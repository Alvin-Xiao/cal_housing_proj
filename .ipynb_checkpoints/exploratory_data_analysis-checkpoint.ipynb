# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('housing_cleaned.csv')
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        near bay
# 1      2401.0      1138.0         8.3014            358500.0        near bay
# 2       496.0       177.0         7.2574            352100.0        near bay
# 3       558.0       219.0         5.6431            341300.0        near bay
# 4       565.0       259.0         3.8462            342200.0        near bay

# %%
# get summary of data

df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20430.000000  20430.000000        20430.000000  20430.000000
# mean    -119.570604     35.632999           28.635291   2636.812188
# std        2.003659      2.136235           12.591329   2185.275419
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1450.250000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.720000           37.000000   3143.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20430.000000  20430.000000  20430.000000   20430.000000
# mean       537.928879   1425.145032    499.494714       3.871544
# std        421.386931   1133.173287    382.292417       1.899135
# min          1.000000      5.000000      1.000000       0.499900
# ...

# %%
# sort between categorical and numerical features

num_vars = df.drop(columns='ocean_proximity', axis=1).columns

# %%
# univariate analysis on numerical features

for var in num_vars:
    print(var)
    plt.subplot(1, 2, 1)
    plt.hist(df[var])
    plt.subplot(1, 2, 2)
    plt.boxplot(df[var], vert=False)
    plt.show()
# Out:
# longitude
# latitude
# housing_median_age
# total_rooms
# total_bedrooms
# population
# households
# median_income
# median_house_value

# %%
# univariate analysis on categorical feature

print('ocean_proximity')
plt.bar(df['ocean_proximity'].value_counts().index, df['ocean_proximity'].value_counts())
# Out:
# ocean_proximity
# <BarContainer object of 5 artists>

# %%
# apply log transformation to right skewed distributions

from scipy.stats import boxcox

for var in ['total_rooms', 'total_bedrooms', 'population', 'households']:
    data = boxcox(df[var], 0)
    plt.subplot(1, 2, 1)
    plt.hist(df[var])
    plt.subplot(1, 2, 2)
    plt.hist(data)
    plt.show()
    df[var] = data

# %%
# bivariate analyses on numerical features

sns.pairplot(df)

# %%
pd.pivot_table(df, index='ocean_proximity', values='median_house_value')
# Out:
#                  median_house_value
# ocean_proximity
# <1h ocean             240255.842909
# inland                124893.674623
# island                380440.000000
# near bay              259279.292070
# near ocean            249042.355023

# %%
ocean_data = df.groupby('ocean_proximity')['median_house_value'].mean().sort_values(ascending=False).bar()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-70-be88412fe486> in <module>
# ----> 1 ocean_data = df.groupby('ocean_proximity')['median_house_value'].mean().sort_values(ascending=False).bar()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'bar'
